# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train = pd.read_csv("../data/processed/X_train.csv")
X_test = pd.read_csv("../data/processed/X_test.csv")
y_train = pd.read_csv("../data/processed/y_train.csv")
y_test = pd.read_csv("../data/processed/y_test.csv")

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=0.95, random_state=42)
X_train_pca1 = pca.fit_transform(X_train)
X_test_pca1 = pca.transform(X_test)

print(f"Original features: {X_train.shape[1]}")
print(f"PCA components: {X_train_pca1.shape[1]}")
print(f"Variance explained by top 5 components: {pca.explained_variance_ratio_[:5]}")
# Out:
# Original features: 33
# PCA components: 26
# Variance explained by top 5 components: [0.06886209 0.06194989 0.05097094 0.04915893 0.04576112]

# %%
plt.figure(figsize=(10,7))
plt.scatter(
    X_train_pca2[:,0], 
    X_train_pca2[:,1],
    c=y_train.values.ravel(), 
    cmap="coolwarm",
    alpha=0.6,
    s=10
)

plt.title("PCA 2-Component Clusters (Returning vs Not Returning)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.show()
